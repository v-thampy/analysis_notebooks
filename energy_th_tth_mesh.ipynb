# %%
# %matplotlib widget

import os, glob, re
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import xrayutilities as xu

import ipywidgets as ipw
from ipywidgets import interact

import fabio
from silx.io.specfile import SpecFile

from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.widgets import RectangleSelector

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Functions

# %%
def get_single_image(fname, n, mask=None):
    imgs = fabio.open(fname)
    img = imgs.get_frame(n).data.astype(float)
    
    if mask is not None:
        img[mask == 1] = np.nan
        
    img[514:551, :] = np.nan
    img[0, 1029] = np.nan
        
    return img

# %% [markdown]
# ## Paths

# %%
base_path = r'/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO'

scan_dir = 'energy_th_tth_mesh'

data_path = os.path.join(base_path, scan_dir)
img_path = os.path.join(data_path, 'images')

scan_dirs = [scan_dir]
spec_fnames = {scan_dir:os.path.join(data_path, scan_dir) for scan_dir in scan_dirs}
img_h5s = {scan_dir:glob.glob(os.path.join(img_path, f'{scan_dir}*master.h5')) for scan_dir in scan_dirs}

img_files = glob.glob(os.path.join(img_path, f'{scan_dir}*master.h5'))
scans = {os.path.basename(img_file)[:-10]:img_file for img_file in img_files}

scans
# Out:
# {'energy_th_tth_mesh_scan003': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan003_master.h5',
#  'energy_th_tth_mesh_scan004': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan004_master.h5',
#  'energy_th_tth_mesh_scan005': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan005_master.h5',
#  'energy_th_tth_mesh_scan006': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan006_master.h5',
#  'energy_th_tth_mesh_scan007': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan007_master.h5',
#  'energy_th_tth_mesh_scan008': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan008_master.h5',
#  'energy_th_tth_mesh_scan009': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan009_master.h5',
#  'energy_th_tth_mesh_scan010': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan010_master.h5',
#  'energy_th_tth_mesh_scan011': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan011_master.h5',
#  'energy_th_tth_mesh_scan012': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan012_master.h5',
#  'energy_th_tth_mesh_scan013': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan013_master.h5',
#  'energy_th_tth_mesh_scan014': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan014_master.h5',
#  'energy_th_tth_mesh_scan015': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan015_master.h5',
#  'energy_th_tth_mesh_scan016': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan016_master.h5',
#  'energy_th_tth_mesh_scan017': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan017_master.h5',
#  'energy_th_tth_mesh_scan018': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan018_master.h5',
#  'energy_th_tth_mesh_scan019': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan019_master.h5',
#  'energy_th_tth_mesh_scan020': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan020_master.h5',
#  'energy_th_tth_mesh_scan021': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan021_master.h5',
#  'energy_th_tth_mesh_scan022': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan022_master.h5',
#  'energy_th_tth_mesh_scan023': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan023_master.h5',
#  'energy_th_tth_mesh_scan024': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan024_master.h5',
#  'energy_th_tth_mesh_scan025': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan025_master.h5',
#  'energy_th_tth_mesh_scan026': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan026_master.h5',
#  'energy_th_tth_mesh_scan027': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan027_master.h5',
#  'energy_th_tth_mesh_scan028': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan028_master.h5',
#  'energy_th_tth_mesh_scan029': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan029_master.h5',
#  'energy_th_tth_mesh_scan030': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan030_master.h5',
#  'energy_th_tth_mesh_scan031': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan031_master.h5',
#  'energy_th_tth_mesh_scan032': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan032_master.h5',
#  'energy_th_tth_mesh_scan033': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan033_master.h5',
#  'energy_th_tth_mesh_scan034': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan034_master.h5',
#  'energy_th_tth_mesh_scan035': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan035_master.h5',
#  'energy_th_tth_mesh_scan036': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan036_master.h5',
#  'energy_th_tth_mesh_scan037': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan037_master.h5',
#  'energy_th_tth_mesh_scan038': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan038_master.h5',
#  'energy_th_tth_mesh_scan039': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan039_master.h5',
#  'energy_th_tth_mesh_scan040': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan040_master.h5',
#  'energy_th_tth_mesh_scan041': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan041_master.h5',
#  'energy_th_tth_mesh_scan042': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan042_master.h5',
#  'energy_th_tth_mesh_scan043': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan043_master.h5',
#  'energy_th_tth_mesh_scan044': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan044_master.h5',
#  'energy_th_tth_mesh_scan045': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan045_master.h5',
#  'energy_th_tth_mesh_scan046': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan046_master.h5',
#  'energy_th_tth_mesh_scan047': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan047_master.h5',
#  'energy_th_tth_mesh_scan048': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan048_master.h5',
#  'energy_th_tth_mesh_scan049': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan049_master.h5',
#  'energy_th_tth_mesh_scan050': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan050_master.h5',
#  'energy_th_tth_mesh_scan051': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan051_master.h5',
#  'energy_th_tth_mesh_scan052': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan052_master.h5',
#  'energy_th_tth_mesh_scan053': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan053_master.h5',
#  'energy_th_tth_mesh_scan054': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan054_master.h5',
#  'energy_th_tth_mesh_scan055': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan055_master.h5',
#  'energy_th_tth_mesh_scan056': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan056_master.h5',
#  'energy_th_tth_mesh_scan057': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan057_master.h5',
#  'energy_th_tth_mesh_scan058': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan058_master.h5',
#  'energy_th_tth_mesh_scan059': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan059_master.h5',
#  'energy_th_tth_mesh_scan060': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan060_master.h5',
#  'energy_th_tth_mesh_scan061': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan061_master.h5',
#  'energy_th_tth_mesh_scan062': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan062_master.h5',
#  'energy_th_tth_mesh_scan063': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan063_master.h5',
#  'energy_th_tth_mesh_scan064': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan064_master.h5',
#  'energy_th_tth_mesh_scan065': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan065_master.h5',
#  'energy_th_tth_mesh_scan066': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan066_master.h5',
#  'energy_th_tth_mesh_scan067': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan067_master.h5',
#  'energy_th_tth_mesh_scan068': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan068_master.h5',
#  'energy_th_tth_mesh_scan069': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan069_master.h5',
#  'energy_th_tth_mesh_scan070': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan070_master.h5',
#  'energy_th_tth_mesh_scan071': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan071_master.h5',
#  'energy_th_tth_mesh_scan072': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan072_master.h5',
#  'energy_th_tth_mesh_scan073': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan073_master.h5',
#  'energy_th_tth_mesh_scan074': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan074_master.h5',
#  'energy_th_tth_mesh_scan075': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan075_master.h5',
#  'energy_th_tth_mesh_scan076': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan076_master.h5',
#  'energy_th_tth_mesh_scan077': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan077_master.h5',
#  'energy_th_tth_mesh_scan078': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan078_master.h5',
#  'energy_th_tth_mesh_scan079': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan079_master.h5',
#  'energy_th_tth_mesh_scan080': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan080_master.h5',
#  'energy_th_tth_mesh_scan081': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan081_master.h5',
#  'energy_th_tth_mesh_scan082': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan082_master.h5',
#  'energy_th_tth_mesh_scan083': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan083_master.h5',
#  'energy_th_tth_mesh_scan084': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan084_master.h5',
#  'energy_th_tth_mesh_scan085': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan085_master.h5',
#  'energy_th_tth_mesh_scan086': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan086_master.h5',
#  'energy_th_tth_mesh_scan087': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan087_master.h5',
#  'energy_th_tth_mesh_scan088': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan088_master.h5',
#  'energy_th_tth_mesh_scan089': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan089_master.h5',
#  'energy_th_tth_mesh_scan090': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/energy_th_tth_mesh/images/energy_th_tth_mesh_scan090_master.h5'}

# %% [markdown]
# ## Show raw images

# %%
f1, f1_ax1 = plt.subplots(figsize=(5, 4), layout='tight')

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

scan_widget = ipw.Dropdown(options=sorted(list(scans.keys())), value=list(scans.keys())[-1])
nimage_widget = ipw.IntSlider(min=0, max=1, step=1)
vminmax_widget = ipw.FloatRangeSlider(min=0, max=100, value=[5, 95], step=0.5)

@interact(
    scan=scan_widget,
    n=nimage_widget,
    vminmax=vminmax_widget
)
def show_raw_image(scan, n, vminmax):
    [ax.cla() for ax in f1.get_axes()]
    
    img_fname = scans[scan]
    ims = fabio.open(img_fname)
    nimage_widget.max = ims.nframes - 1
    
    im_arr = get_single_image(img_fname, n)
    im_arr[im_arr > 1e8] = np.nan
    
    minmax = np.nanpercentile(im_arr, vminmax)
    im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
    plt.colorbar(im, cax=f1_cax1)
    
    
    spec_scan_number = int(scan[-3:]) - 1
    spec_file = SpecFile(spec_fnames[scan_dir])
    spec_scan = spec_file[spec_scan_number]
    
    print(str(spec_scan.data_column_by_name('H')[n])[:5]+'  0  '+
              str(spec_scan.data_column_by_name('L')[n])[:5] )
#     def onselect(eclick, erelease):
#         print(eclick.xdata, eclick.ydata)
#         print(erelease.xdata, erelease.ydata)
    
#     props = dict(facecolor='blue', alpha=0.5)
#     rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
#     rect_selector.add_state('square')
# Out:
# interactive(children=(Dropdown(description='scan', index=87, options=('energy_th_tth_mesh_scan003', 'energy_th…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Show raw image with HKL

# %%
f1, f1_ax1 = plt.subplots(nrows=1,ncols=3,figsize=(8, 3), layout='tight')

divider = make_axes_locatable(f1_ax1[0])
# f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
# f1.add_axes(f1_cax1)

scan_widget = ipw.Dropdown(options=sorted(list(scans.keys())), value=list(scans.keys())[-1])
nimage_widget = ipw.IntSlider(min=0, max=1, step=1)
vminmax_widget = ipw.FloatRangeSlider(min=0, max=100, value=[5, 95], step=0.5)

qconversion = xu.QConversion(sampleAxis = ['z-','y+','z-'], detectorAxis = ['z-'], r_i = [0,1,0])

@interact(
    scan=scan_widget,
    n=nimage_widget,
    vminmax=vminmax_widget
)
def show_raw_image(scan, n, vminmax):
    [ax.cla() for ax in f1.get_axes()]
    
    img_fname = scans[scan]
    ims = fabio.open(img_fname)
    nimage_widget.max = ims.nframes - 1
    
    im_arr = get_single_image(img_fname, n)
    im_arr[im_arr > 1e8] = np.nan
    
    minmax = np.nanpercentile(im_arr, vminmax)
    im = f1_ax1[0].imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
    # plt.colorbar(im, cax=f1_cax1)
    
    spec_scan_number = int(scan[-3:]) - 1
    spec_file = SpecFile(spec_fnames[scan_dir])
    spec_scan = spec_file[spec_scan_number]
    
    print(str(spec_scan.data_column_by_name('H')[n])[:5]+'  0  '+
              str(spec_scan.data_column_by_name('L')[n])[:5] +' '+ str(spec_scan_number))
    
    
    for line in spec_scan.header:
        if line[:3] == '#G3':
            UB = np.array(line.split(' ')[-9:]).astype(float).reshape([3,3])
        if line[:3] == '#P0':
            angles = np.array(line.split(' ')[1:-2]).astype(float)
        if line[:4] == '#P14':
            energy = np.array(line.split(' ')[4]).astype(float)
        if line[:2] == '#S':
            print(line)

    hxrd = xu.HXRD( [0,1,0], [0,0,1], en = energy, qconv =  qconversion)

    hxrd.Ang2Q.init_area(
            'x-', 'z-',
            cch1=521, cch2=530,
            Nch1=1065, Nch2=1030,
            pwidth1=0.075, pwidth2=0.075,
            distance=535
        )
            
    try:
        tt = spec_scan.data_column_by_name('del')[n]
    except:
        tt = angles[0]

    try:
        eta = spec_scan.data_column_by_name('eta')[n]
    except:
        eta = angles[1]

    try:
        chi = spec_scan.data_column_by_name('chi')[n]
    except:
        chi = angles[2]

    try:
        phi = spec_scan.data_column_by_name('phi')[n]
    except:
        phi = angles[3]
    qx, qy, qz = hxrd.Ang2Q.area(eta, chi, phi, tt, UB=UB)
    
    im1 = f1_ax1[1].imshow(qx)
    plt.title('H')
    im2 = f1_ax1[2].imshow(qz)
    plt.title('L')
# Out:
# interactive(children=(Dropdown(description='scan', index=87, options=('energy_th_tth_mesh_scan003', 'energy_th…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
spec_file = SpecFile(spec_fnames['energy_th_tth_mesh'])
spec_scan = spec_file[40]

# %%
spec_scan.data_column_by_name('eta')
# Out:
# array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ,
#         5.4,  5.8,  6.2,  6.6,  7. ,  7.4,  7.8,  8.2,  8.6,  9. ,  9.4,
#         9.8, 10.2, 10.6, 11. , 11.4, 11.8, 12.2, 12.6, 13. , 13.4, 13.8,
#        14.2, 14.6, 15. , 15.4, 15.8, 16.2, 16.6, 17. , 17.4, 17.8, 18.2,
#        18.6, 19. , 19.4, 19.8, 20.2, 20.6, 21. , 21.4, 21.8, 22.2, 22.6,
#        23. , 23.4, 23.8, 24.2, 24.6, 25. , 25.4, 25.8, 26.2, 26.6, 27. ,
#        27.4, 27.8, 28.2, 28.6, 29. , 29.4, 29.8, 30.2, 30.6, 31. , 31.4,
#        31.8, 32.2, 32.6, 33. , 33.4, 33.8, 34.2, 34.6, 35. , 35.4, 35.8,
#        36.2, 36.6, 37. , 37.4, 37.8, 38.2, 38.6, 39. , 39.4, 39.8, 40.2,
#        40.6, 41. , 41.4, 41.8, 42.2, 42.6, 43. , 43.4, 43.8, 44.2, 44.6,
#        45. ])

# %%
spec_file = SpecFile(spec_fnames[scan_dir])
spec_scan = spec_file[40]

# %%
# 3.90266 3.90266 3.3 90 90 90 
# 1.60997507 1.60997507 1.903995548 90 90 90 
# 0 0 1 
# 1 0 3 

# 26.05 12.37000001 91 -2.187500058e-06 -3.59375008e-06 0 
# 89.33 28.28000001 91 -2.187500058e-06 -3.59375008e-06 0

# %% [markdown]
# ### Get ROI extents

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5), layout="constrained")

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

extent = []

im_arr = get_single_image(scans[list(scans.keys())[-1]], 0)
im_arr[im_arr > 1e8] = np.nan
   
minmax = np.nanpercentile(im_arr, [5, 95])
im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
plt.colorbar(im, cax=f1_cax1)
    
def onselect(eclick, erelease):
    global extent

    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [int(x.round()) for x in [x1, y1, x2, y2]]
    
    print(eclick.xdata, eclick.ydata)
    print(erelease.xdata, erelease.ydata)
    
props = dict(facecolor='blue', alpha=0.5)
rect_selector = RectangleSelector(f1_ax1, onselect, 
                                  useblit=True,
                                  button=[1, 3],  # disable middle button
                                  minspanx=5, minspany=5,
                                  spancoords='pixels',
                                  props=props, interactive=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Show ROI sum

# %%
f2, f2_ax1 = plt.subplots(figsize=(6, 4), layout='tight')

scan_widget = ipw.Dropdown(options=list(scans.keys()), value=list(scans.keys())[-1])

@interact(
    scan=scan_widget,
)
def show_ROI_sum(scan):
    [ax.cla() for ax in f2.get_axes()]

    spec_scan_number = int(scan[-3:]) - 1
    print(spec_scan_number)
    spec_file = SpecFile(spec_fnames[scan_dir])
    spec_scan = spec_file[spec_scan_number]

    x_col = spec_file.command(spec_scan_number).split()[1]
    x_data = spec_scan.data_column_by_name(x_col)

    img_fname = scans[scan]
    ims = fabio.open(img_fname)
    
    roi_sum = []
    for im in ims:
        im_arr = im.data.astype(float)
        im_arr[im_arr > 1e8] = np.nan
        # img = imgs.get_frame(n).data
        im_arr[514:551, :] = np.nan
        im_arr[0, 1029] = np.nan
    
        im_roi = im_arr[extent[1]:extent[3], extent[0]:extent[2]]
        roi_sum.append(np.nansum(im_roi))
        
    
    f2_ax1.plot(x_data, roi_sum, 'o-')
    f2_ax1.set_xlabel(x_col)
    f2_ax1.set_ylabel('Intensity [a.u.]')
# Out:
# interactive(children=(Dropdown(description='scan', options=('energy_th_tth_mesh_scan003',), value='energy_th_t…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
<pre>H K L =  -0.98649  0.41394  2.9368	 Lambda = 1.4879 Two Theta = 73.09

    Alpha      Beta       Psi       Tau       Qaz       Naz     Omega
  31.7395   36.3642   83.0173   20.0156   90.0000   66.4544   -2.2410

       del        eta        chi        phi         nu         mu 
  73.08979   34.30387   70.69531   82.80613    0.00000    0.00000 
</pre>

# %%
spec_fnames
# Out:
# {'find_ubr': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/find_ubr'}

# %%
spec_scan = spec_file[2]

# %%
x_data = spec_scan.data_column_by_name('eta')

# %%
img_files = img_h5s[sc]

img_fnames = [os.path.basename(img_file) for img_file in img_files]

# %% [markdown]
# ## Show raw images

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5))

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

scan_widget = ipw.Dropdown(options=img_fnames)
nimage_widget = ipw.IntSlider(min=0, max=1, step=1)
vminmax_widget = ipw.FloatRangeSlider(min=0, max=100, value=[5, 95], step=0.5)

@interact(
    scan=scan_widget,
    n=nimage_widget,
    vminmax=vminmax_widget
)
def show_raw_image(scan, n, vminmax):
    [ax.cla() for ax in f1.get_axes()]
    
    ims = fabio.open(scan)
    nimage_widget.max = ims.nframes - 1
    
    im_arr = get_single_image(scan, n)
    im_arr[im_arr > 1e8] = np.nan
    
    minmax = np.nanpercentile(im_arr, vminmax)
    im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
    plt.colorbar(im, cax=f1_cax1)
    
    def onselect(eclick, erelease):
        print(eclick.xdata, eclick.ydata)
        print(erelease.xdata, erelease.ydata)
    
    props = dict(facecolor='blue', alpha=0.5)
    rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
    rect_selector.add_state('square')
# Out:
# interactive(children=(Dropdown(description='scan', options=('find_ubr_scan003_master.h5', 'find_ubr_scan002_ma…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Show ROI Sums

# %% [markdown]
# ### Get ROI extents

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5), layout="constrained")

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

ims = fabio.open(scans[0])

im_arr = get_single_image(scans[0], 0)
im_arr[im_arr > 1e8] = np.nan
   
minmax = np.nanpercentile(im_arr, [5, 95])
im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
plt.colorbar(im, cax=f1_cax1)
    
def onselect(eclick, erelease):
    global extent

    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [int(x.round()) for x in [x1, y1, x2, y2]]
    
    print(eclick.xdata, eclick.ydata)
    print(erelease.xdata, erelease.ydata)
    
    
props = dict(facecolor='blue', alpha=0.5)
rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
rect_selector.add_state('square')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Show ROI sum

# %%
extent
# Out:
# [536, 241, 758, 463]

# %%
f2, f2_ax1 = plt.subplots(figsize=(6, 4))

scan_widget = ipw.Dropdown(options=scans)

@interact(
    scan=scan_widget,
)
def show_ROI_sum(scan):
    [ax.cla() for ax in f2.get_axes()]
    
    ims = fabio.open(scan)

    roi_sum = []
    for im in ims:
        im_arr = im.data
        im_roi = im_arr[extent[1]:extent[3], extent[0]:extent[2]]
        roi_sum.append(np.nansum(im_roi))
        
    
    f2_ax1.plot(x_data, roi_sum, 'o-')
    f2_ax1
# Out:
# interactive(children=(Dropdown(description='scan', options=('/msd_data/checkout/bl17-2/det_psic_test/images/rm…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
int((extent[0]-0.4).round())
# Out:
# 324

# %%
from matplotlib.widgets import EllipseSelector, RectangleSelector
import numpy as np
import matplotlib.pyplot as plt


def select_callback(eclick, erelease):
    """
    Callback for line selection.

    *eclick* and *erelease* are the press and release events.
    """
    global extent
    
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [x1, y1, x2, y2
             ]
    print(f"({x1:3.2f}, {y1:3.2f}) --> ({x2:3.2f}, {y2:3.2f})")
    print(f"The buttons you used were: {eclick.button} {erelease.button}")
    

def toggle_selector(event):
    print('Key pressed.')
    if event.key == 't':
        for selector in selectors:
            name = type(selector).__name__
            if selector.active:
                print(f'{name} deactivated.')
                selector.set_active(False)
            else:
                print(f'{name} activated.')
                selector.set_active(True)


fig = plt.figure(layout='constrained')
axs = fig.subplots(2)

N = 100000  # If N is large one can see improvement by using blitting.
x = np.linspace(0, 10, N)

selectors = []
for ax, selector_class in zip(axs, [RectangleSelector, EllipseSelector]):
    ax.plot(x, np.sin(2*np.pi*x))  # plot something
    ax.set_title(f"Click and drag to draw a {selector_class.__name__}.")
    selectors.append(selector_class(
        ax, select_callback,
        useblit=True,
        button=[1, 3],  # disable middle button
        minspanx=5, minspany=5,
        spancoords='pixels',
        interactive=True))
    fig.canvas.mpl_connect('key_press_event', toggle_selector)
axs[0].set_title("Press 't' to toggle the selectors on and off.\n"
                 + axs[0].get_title())
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
extent
# Out:
# [3.8282941186148296,
#  -0.5092067238051216,
#  5.959990897119711,
#  0.4896137238032865]
