# %%
# %matplotlib widget

import os, glob, re
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import xrayutilities as xu

import ipywidgets as ipw
from ipywidgets import interact

import fabio
from silx.io.specfile import SpecFile

from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.widgets import RectangleSelector

# %% [markdown]
# ## Functions

# %%
def get_single_image(fname, n, mask=None):
    imgs = fabio.open(fname)
    img = imgs.get_frame(n).data.astype(float)
    
    if mask is not None:
        img[mask == 1] = np.nan
        
    img[514:551, :] = np.nan
    img[0, 1029] = np.nan
        
    return img


# Function to be executed after selection
def onselect_function(eclick, erelease):
   
    # Obtain (xmin, xmax, ymin, ymax) values
    # for rectangle selector box using extent attribute.
    extent = rect_selector.extents
    print("Extents: ", extent)
    
    return extent
 
    # Zoom the selected part
    # Set xlim range for plot as xmin to xmax
    # of rectangle selector box.
    #plt.xlim(extent[0], extent[1])
     
    # Set ylim range for plot as ymin to ymax
    # of rectangle selector box.
    #plt.ylim(extent[2], extent[3])
    

def get_tiff_data(tiff_file, mask=None):
    img = (fabio.open(tiff_file).data).astype(float)
    
    if mask is not None:
        img[mask == 1] = np.nan

    return img

# %% [markdown]
# ## Paths

# %%
base_path = r'/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO'

scan_dir = 'find_ubr'

data_path = os.path.join(base_path, scan_dir)
img_path = os.path.join(data_path, 'images')

scan_dirs = ['find_ubr']
spec_fnames = {scan_dir:os.path.join(data_path, scan_dir) for scan_dir in scan_dirs}
img_h5s = {scan_dir:glob.glob(os.path.join(img_path, f'{scan_dir}*master.h5')) for scan_dir in scan_dirs}

img_files = glob.glob(os.path.join(img_path, f'{scan_dir}*master.h5'))
img_tiffs = glob.glob(os.path.join(img_path, f'{scan_dir}*master.h5'))
scans = {os.path.basename(img_file)[:-10]:img_file for img_file in img_files}

# %%
glob.glob(os.path.join(img_path, f'{scan_dir}*'))
# Out:
# ['/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan003_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan003_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan002_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan002_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan007_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan007_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan006_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan006_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan008_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan008_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan009_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan009_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan010_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan010_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan011_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan011_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan012_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan012_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan013_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan013_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan014_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan014_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan015_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan015_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan017_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan017_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan019',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan019_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan019_master.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan020',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan020_data_000001.h5',
#  '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/images/find_ubr_scan020_master.h5']

# %% [markdown]
# ## Show raw images

# %%
f1, f1_ax1 = plt.subplots(figsize=(5, 4), layout='tight')

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

scan_widget = ipw.Dropdown(options=list(scans.keys()))
nimage_widget = ipw.IntSlider(min=0, max=1, step=1)
vminmax_widget = ipw.FloatRangeSlider(min=0, max=100, value=[5, 95], step=0.5)

@interact(
    scan=scan_widget,
    n=nimage_widget,
    vminmax=vminmax_widget
)
def show_raw_image(scan, n, vminmax):
    [ax.cla() for ax in f1.get_axes()]
    
    img_fname = scans[scan]
    nimage_widget.max = 10
    
    im_arr = fabio.open(img_fname[:-10] +'/'+scan +'_' +str(n).zfill(4)+'.tif')
    # im_arr[im_arr > 1e8] = np.nan
    print('loaded')

    minmax = [0, 20]  #np.nanpercentile(im_arr, vminmax)
    im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
    plt.colorbar(im, cax=f1_cax1)

    def onselect(eclick, erelease):
        print(eclick.xdata, eclick.ydata)
        print(erelease.xdata, erelease.ydata)

    props = dict(facecolor='blue', alpha=0.5)
    rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
    rect_selector.add_state('square')
# Out:
# /tmp/ipykernel_3980624/4150970936.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   f1, f1_ax1 = plt.subplots(figsize=(5, 4), layout='tight')
# interactive(children=(Dropdown(description='scan', options=('find_ubr_scan003', 'find_ubr_scan002', 'find_ubr_…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f1, f1_ax1 = plt.subplots(figsize=(5, 4), layout='tight')

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

scan = 19 
n = 1

img_fname = scans['find_ubr_scan0'+ str(scan)]
img = fabio.open(img_fname[:-10] +'/'+ scan_dir+'_scan'+str(scan).zfill(3) +'_' +str(n).zfill(4)+'.tif')
im = f1_ax1.imshow(img.data)#, vmin=minmax[0], vmax=minmax[1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
[ax.cla() for ax in f1.get_axes()]
    
img_fname = scans['find_ubr_scan019']
nimage_widget.max = 2

im_arr = fabio.open(img_fname[:-10] +'/'+scan +'_' +str(n).zfill(4)+'.tif')
# im_arr[im_arr > 1e8] = np.nan
print('loaded')

minmax = [0, 20]  #np.nanpercentile(im_arr, vminmax)
im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
plt.colorbar(im, cax=f1_cax1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 6
#       3 img_fname = scans['find_ubr_scan019']
#       4 nimage_widget.max = 10
# ----> 6 im_arr = fabio.open(img_fname[:-10] +'/'+scan +'_' +str(n).zfill(4)+'.tif')
#       7 # im_arr[im_arr > 1e8] = np.nan
#       8 print('loaded')
#
# TypeError: can only concatenate str (not "int") to str

# %%
im_arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 im_arr
#
# NameError: name 'im_arr' is not defined

# %%
str(scan).zfill(3)
# Out:
# '019'

# %% [markdown]
# ### Get ROI extents

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5), layout="constrained")

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

#ims = fabio.open(scans[scan])

im_arr = get_single_image(scans[list(scans.keys())[-1]], 0)
im_arr[im_arr > 1e8] = np.nan
   
minmax = np.nanpercentile(im_arr, [5, 95])
im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
plt.colorbar(im, cax=f1_cax1)
    
def onselect(eclick, erelease):
    global extent

    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [int(x.round()) for x in [x1, y1, x2, y2]]
    
    print(eclick.xdata, eclick.ydata)
    print(erelease.xdata, erelease.ydata)
    
    
props = dict(facecolor='blue', alpha=0.5)
rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
rect_selector.add_state('square')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Show ROI sum

# %% [markdown]
# a = re.search(r"\s", command)
# a.

# %% [markdown]
# command = spec_file.command(18)
# #motor =

# %%
f2, f2_ax1 = plt.subplots(figsize=(6, 4), layout='tight')

scan_widget = ipw.Dropdown(options=list(scans.keys()), value=list(scans.keys())[-1])

@interact(
    scan=scan_widget,
)
def show_ROI_sum(scan):
    [ax.cla() for ax in f2.get_axes()]

    spec_scan_number = int(scan[-3:]) - 1
    spec_file = SpecFile(spec_fnames[scan_dir])
    spec_scan = spec_file[spec_scan_number]

    x_col = 'energy'
    x_data = spec_scan.data_column_by_name(x_col)


    img_fname = scans[scan]
    ims = fabio.open(img_fname)
    
    roi_sum = []
    for im in ims:
        im_arr = im.data.astype(float)
        im_arr[im_arr > 1e8] = np.nan
        # img = imgs.get_frame(n).data
        im_arr[514:551, :] = np.nan
        im_arr[0, 1029] = np.nan
    
        im_roi = im_arr[extent[1]:extent[3], extent[0]:extent[2]]
        roi_sum.append(np.nansum(im_roi))
        
    
    f2_ax1.plot(x_data, roi_sum, 'o-')
    f2_ax1.set_xlabel(x_col)
    f2_ax1.set_ylabel('Intensity [a.u.]')
# Out:
# interactive(children=(Dropdown(description='scan', index=13, options=('find_ubr_scan003', 'find_ubr_scan002', …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
spec_fnames
# Out:
# {'find_ubr': '/msd_data/checkout/bl17-2/Aug2023_Li/NNO_STO/find_ubr/find_ubr'}

# %%
spec_scan = spec_file[2]

# %%
x_data = spec_scan.data_column_by_name('eta')

# %%
img_files = img_h5s[sc]

img_fnames = [os.path.basename(img_file) for img_file in img_files]

# %% [markdown]
# ## Show raw images

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5))

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

scan_widget = ipw.Dropdown(options=img_fnames)
nimage_widget = ipw.IntSlider(min=0, max=1, step=1)
vminmax_widget = ipw.FloatRangeSlider(min=0, max=100, value=[5, 95], step=0.5)

@interact(
    scan=scan_widget,
    n=nimage_widget,
    vminmax=vminmax_widget
)
def show_raw_image(scan, n, vminmax):
    [ax.cla() for ax in f1.get_axes()]
    
    ims = fabio.open(scan)
    nimage_widget.max = ims.nframes - 1
    
    im_arr = get_single_image(scan, n)
    im_arr[im_arr > 1e8] = np.nan
    
    minmax = np.nanpercentile(im_arr, vminmax)
    im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
    plt.colorbar(im, cax=f1_cax1)
    
    def onselect(eclick, erelease):
        print(eclick.xdata, eclick.ydata)
        print(erelease.xdata, erelease.ydata)
    
    props = dict(facecolor='blue', alpha=0.5)
    rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
    rect_selector.add_state('square')
# Out:
# interactive(children=(Dropdown(description='scan', options=('find_ubr_scan003_master.h5', 'find_ubr_scan002_ma…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Show ROI Sums

# %% [markdown]
# ### Get ROI extents

# %%
f1, f1_ax1 = plt.subplots(figsize=(6, 5), layout="constrained")

divider = make_axes_locatable(f1_ax1)
f1_cax1 = divider.append_axes("right", size="5%", pad=0.1)
f1.add_axes(f1_cax1)

ims = fabio.open(scans[0])

im_arr = get_single_image(scans[0], 0)
im_arr[im_arr > 1e8] = np.nan
   
minmax = np.nanpercentile(im_arr, [5, 95])
im = f1_ax1.imshow(im_arr, vmin=minmax[0], vmax=minmax[1])
plt.colorbar(im, cax=f1_cax1)
    
def onselect(eclick, erelease):
    global extent

    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [int(x.round()) for x in [x1, y1, x2, y2]]
    
    print(eclick.xdata, eclick.ydata)
    print(erelease.xdata, erelease.ydata)
    
    
props = dict(facecolor='blue', alpha=0.5)
rect_selector = RectangleSelector(f1_ax1, onselect, props=props, interactive=True)
rect_selector.add_state('square')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Show ROI sum

# %%
extent
# Out:
# [536, 241, 758, 463]

# %%
f2, f2_ax1 = plt.subplots(figsize=(6, 4))

scan_widget = ipw.Dropdown(options=scans)

@interact(
    scan=scan_widget,
)
def show_ROI_sum(scan):
    [ax.cla() for ax in f2.get_axes()]
    
    ims = fabio.open(scan)

    roi_sum = []
    for im in ims:
        im_arr = im.data
        im_roi = im_arr[extent[1]:extent[3], extent[0]:extent[2]]
        roi_sum.append(np.nansum(im_roi))
        
    
    f2_ax1.plot(x_data, roi_sum, 'o-')
    f2_ax1
# Out:
# interactive(children=(Dropdown(description='scan', options=('/msd_data/checkout/bl17-2/det_psic_test/images/rm…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
int((extent[0]-0.4).round())
# Out:
# 324

# %%
from matplotlib.widgets import EllipseSelector, RectangleSelector
import numpy as np
import matplotlib.pyplot as plt


def select_callback(eclick, erelease):
    """
    Callback for line selection.

    *eclick* and *erelease* are the press and release events.
    """
    global extent
    
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    
    extent = [x1, y1, x2, y2
             ]
    print(f"({x1:3.2f}, {y1:3.2f}) --> ({x2:3.2f}, {y2:3.2f})")
    print(f"The buttons you used were: {eclick.button} {erelease.button}")
    

def toggle_selector(event):
    print('Key pressed.')
    if event.key == 't':
        for selector in selectors:
            name = type(selector).__name__
            if selector.active:
                print(f'{name} deactivated.')
                selector.set_active(False)
            else:
                print(f'{name} activated.')
                selector.set_active(True)


fig = plt.figure(layout='constrained')
axs = fig.subplots(2)

N = 100000  # If N is large one can see improvement by using blitting.
x = np.linspace(0, 10, N)

selectors = []
for ax, selector_class in zip(axs, [RectangleSelector, EllipseSelector]):
    ax.plot(x, np.sin(2*np.pi*x))  # plot something
    ax.set_title(f"Click and drag to draw a {selector_class.__name__}.")
    selectors.append(selector_class(
        ax, select_callback,
        useblit=True,
        button=[1, 3],  # disable middle button
        minspanx=5, minspany=5,
        spancoords='pixels',
        interactive=True))
    fig.canvas.mpl_connect('key_press_event', toggle_selector)
axs[0].set_title("Press 't' to toggle the selectors on and off.\n"
                 + axs[0].get_title())
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
extent
# Out:
# [3.8282941186148296,
#  -0.5092067238051216,
#  5.959990897119711,
#  0.4896137238032865]
